# %% [markdown]
# # オープンデータの利用と可視化
# 横浜県を解析するよ！

# %%
#マジックファンクション
# %matplotlib inline

# %%
#お馴染みpandasを読み込み
import pandas as pd

# %%
#このアドレスは期間限定なので注意（横浜市が情報を更新したら変更する必要があります。）
#ローカルに保存した方が安心ですね
open_data = "http://www.city.yokohama.lg.jp/ex/stat/opendata/suikei01/e1yokohama1703.csv"

# %%
#文字列が入ってます
open_data
# Out:
# 'http://www.city.yokohama.lg.jp/ex/stat/opendata/suikei01/e1yokohama1703.csv'

# %%
#市区名をインデックスにしてpandas形式のオブジェクトを作成
df = pd.read_csv(open_data, index_col='市区名')

# %%
#今からこれを解析します
df
# Out:
#             年月日  全国地方公共団体コード  面積［平方キロメートル］  世帯数［世帯］  人口総数［人］     男［人］  \
# 市区名
# 横浜市    2017/3/1       141003        435.29  1659702  3728021  1855045
# 鶴見区    2017/3/1       141011         32.38   134439   287334   148559
# 神奈川区   2017/3/1       141020         23.59   120800   239999   122167
# 西区     2017/3/1       141038          6.98    52054    98697    49889
# 中区     2017/3/1       141046         20.93    79401   148939    78199
# 南区     2017/3/1       141054         12.63    96220   194471    96837
# 港南区    2017/3/1       141119         19.86    91538   214171   105219
# 保土ケ谷区  2017/3/1       141062         21.81    93920   206429   102696
# 旭区     2017/3/1       141127         32.78   103492   246213   119449
# 磯子区    2017/3/1       141071         19.02    75311   166414    81933
# 金沢区    2017/3/1       141089         30.68    87019   200479    98227
# 港北区    2017/3/1       141097         31.37   164705   346759   175367
# 緑区     2017/3/1       141135         25.42    75541   181023    89229
# 青葉区    2017/3/1       141178         35.06   126308   310214   151043
# 都筑区    2017/3/1       141186         27.88    81322   211990   105941
# 戸塚区    2017/3/1       141101         35.70   114639   275901   135338
# 栄区     2017/3/1       141151         18.55    50963   121360    59265
# 泉区     2017/3/1       141160         23.56    61257   153624    75157
# 瀬谷区    2017/3/1       141143         17.11    50773   124004    60530
#
#           女［人］  １世帯当たり人員［人］  人口密度［人／平方キロメートル］  届出による前月比増減の世帯数［世帯］  \
# 市区名
# 横浜市    1872976         2.25              8564                -921
# 鶴見区     138775         2.14              8874                 -73
# 神奈川区    117832         1.99             10174                -126
# 西区       48808         1.90             14140                  -3
# 中区       70740         1.88              7116                -101
# 南区       97634         2.02             15398                 -43
# 港南区     108952         2.34             10784                 -46
# 保土ケ谷区   103733         2.20              9465                 -53
# 旭区      126764         2.38              7511                 -28
# 磯子区      84481         2.21              8749                   1
# 金沢区     102252         2.30              6535                 -61
# 港北区     171392         2.11             11054                -126
# 緑区       91794         2.40              7121                 -20
# 青葉区     159171         2.46              8848                -165
# 都筑区     106049         2.61              7604                 -42
# 戸塚区     140563         2.41              7728                 -34
# 栄区       62095         2.38              6542                  10
# 泉区       78467         2.51              6521                   1
# 瀬谷区      63474         2.44              7247                 -12
#
#        届出による前月比増減の人口［人］
# 市区名
# 横浜市               -2137
# 鶴見区                -103
# 神奈川区               -159
# 西区                  -19
# 中区                  -93
# 南区                 -127
# 港南区                -223
# 保土ケ谷区              -112
# 旭区                 -134
# 磯子区                 -34
# 金沢区                -172
# 港北区                -101
# 緑区                  -86
# 青葉区                -304
# 都筑区                -142
# 戸塚区                -125
# 栄区                  -25
# 泉区                  -38
# 瀬谷区                -140

# %%
#リネーム（項目名の変更）も可能
df.rename(columns={'全国地方公共団体コード':'Code'}, inplace=True)

# %%
df
# Out:
#             年月日    Code  面積［平方キロメートル］  世帯数［世帯］  人口総数［人］     男［人］     女［人］  \
# 市区名
# 横浜市    2017/3/1  141003        435.29  1659702  3728021  1855045  1872976
# 鶴見区    2017/3/1  141011         32.38   134439   287334   148559   138775
# 神奈川区   2017/3/1  141020         23.59   120800   239999   122167   117832
# 西区     2017/3/1  141038          6.98    52054    98697    49889    48808
# 中区     2017/3/1  141046         20.93    79401   148939    78199    70740
# 南区     2017/3/1  141054         12.63    96220   194471    96837    97634
# 港南区    2017/3/1  141119         19.86    91538   214171   105219   108952
# 保土ケ谷区  2017/3/1  141062         21.81    93920   206429   102696   103733
# 旭区     2017/3/1  141127         32.78   103492   246213   119449   126764
# 磯子区    2017/3/1  141071         19.02    75311   166414    81933    84481
# 金沢区    2017/3/1  141089         30.68    87019   200479    98227   102252
# 港北区    2017/3/1  141097         31.37   164705   346759   175367   171392
# 緑区     2017/3/1  141135         25.42    75541   181023    89229    91794
# 青葉区    2017/3/1  141178         35.06   126308   310214   151043   159171
# 都筑区    2017/3/1  141186         27.88    81322   211990   105941   106049
# 戸塚区    2017/3/1  141101         35.70   114639   275901   135338   140563
# 栄区     2017/3/1  141151         18.55    50963   121360    59265    62095
# 泉区     2017/3/1  141160         23.56    61257   153624    75157    78467
# 瀬谷区    2017/3/1  141143         17.11    50773   124004    60530    63474
#
#        １世帯当たり人員［人］  人口密度［人／平方キロメートル］  届出による前月比増減の世帯数［世帯］  届出による前月比増減の人口［人］
# 市区名
# 横浜市           2.25              8564                -921             -2137
# 鶴見区           2.14              8874                 -73              -103
# 神奈川区          1.99             10174                -126              -159
# 西区            1.90             14140                  -3               -19
# 中区            1.88              7116                -101               -93
# 南区            2.02             15398                 -43              -127
# 港南区           2.34             10784                 -46              -223
# 保土ケ谷区         2.20              9465                 -53              -112
# 旭区            2.38              7511                 -28              -134
# 磯子区           2.21              8749                   1               -34
# 金沢区           2.30              6535                 -61              -172
# 港北区           2.11             11054                -126              -101
# 緑区            2.40              7121                 -20               -86
# 青葉区           2.46              8848                -165              -304
# 都筑区           2.61              7604                 -42              -142
# 戸塚区           2.41              7728                 -34              -125
# 栄区            2.38              6542                  10               -25
# 泉区            2.51              6521                   1               -38
# 瀬谷区           2.44              7247                 -12              -140

# %%
#末尾だけ見ることもできるよ！
df.tail(3)
# Out:
#           年月日    Code  面積［平方キロメートル］  世帯数［世帯］  人口総数［人］   男［人］   女［人］  \
# 市区名
# 栄区   2017/3/1  141151         18.55    50963   121360  59265  62095
# 泉区   2017/3/1  141160         23.56    61257   153624  75157  78467
# 瀬谷区  2017/3/1  141143         17.11    50773   124004  60530  63474
#
#      １世帯当たり人員［人］  人口密度［人／平方キロメートル］  届出による前月比増減の世帯数［世帯］  届出による前月比増減の人口［人］
# 市区名
# 栄区          2.38              6542                  10               -25
# 泉区          2.51              6521                   1               -38
# 瀬谷区         2.44              7247                 -12              -140

# %% [markdown]
# # 人口データをpandasで抽出

# %%
key_data = ['人口総数［人］','男［人］','女［人］']

# %%
#上の表だと使わないデータが多いので、必要なものを抜き出します。
pp = df[df.Code!=141003][key_data]

# %%
pp
# Out:
#        人口総数［人］    男［人］    女［人］
# 市区名
# 鶴見区     287334  148559  138775
# 神奈川区    239999  122167  117832
# 西区       98697   49889   48808
# 中区      148939   78199   70740
# 南区      194471   96837   97634
# 港南区     214171  105219  108952
# 保土ケ谷区   206429  102696  103733
# 旭区      246213  119449  126764
# 磯子区     166414   81933   84481
# 金沢区     200479   98227  102252
# 港北区     346759  175367  171392
# 緑区      181023   89229   91794
# 青葉区     310214  151043  159171
# 都筑区     211990  105941  106049
# 戸塚区     275901  135338  140563
# 栄区      121360   59265   62095
# 泉区      153624   75157   78467
# 瀬谷区     124004   60530   63474

# %%
from matplotlib import rc

# %%
font = {'family':'IPAGothic'}
rc('font', **font)
from matplotlib import pyplot

# %%
pyplot.style.use('ggplot')

# %%
pp.plot(kind='bar', figsize=(12,6), y=["男［人］","女［人］"], fontsize=17)

# %% [markdown]
# 上のグラフの横軸ラベルが豆腐みたいになっている人もいるかもしれません。
# 解消したい場合は以下のリンクを参照して下さい。
# [http://qiita.com/dodo5522/items/7f9b390698f0322bf224]
#
# 上のリンクだとmatplotlibの設定ファイルの場所の調べ方を書いていません。
# 必要な人は下のコマンドをコピペして使って下さい。
# - import matplotlib
# - matplotlib.matplotlib_fname()

# %%
#人口総数[人]のカラムに含まれる値でソートする。ascendingをTrueにすると昇順になる。
sorted_pp = pp.sort_values(by="人口総数［人］", ascending=False)

# %%
sorted_pp
# Out:
#        人口総数［人］    男［人］    女［人］
# 市区名
# 港北区     346759  175367  171392
# 青葉区     310214  151043  159171
# 鶴見区     287334  148559  138775
# 戸塚区     275901  135338  140563
# 旭区      246213  119449  126764
# 神奈川区    239999  122167  117832
# 港南区     214171  105219  108952
# 都筑区     211990  105941  106049
# 保土ケ谷区   206429  102696  103733
# 金沢区     200479   98227  102252
# 南区      194471   96837   97634
# 緑区      181023   89229   91794
# 磯子区     166414   81933   84481
# 泉区      153624   75157   78467
# 中区      148939   78199   70740
# 瀬谷区     124004   60530   63474
# 栄区      121360   59265   62095
# 西区       98697   49889   48808

# %%
#並べ替えたデータを表示。どの区が人口が多いとかがわかりやすい！
sorted_pp.plot(kind='bar', figsize=(12,6), y=['男［人］', '女［人］'], fontsize=17)
